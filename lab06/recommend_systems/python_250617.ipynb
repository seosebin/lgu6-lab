# %% [markdown]
# # Surprise 라이브러리 활용한 추천 시스템 구축
# - 버전 체크
# - NumPy 버전을 1.26.4 설정 (최신 버전 2.3), 환경설정 할 때 주의

# %%
import surprise 
print(surprise.__version__)
# Out:
# 1.1.4

# %% [markdown]
# # 라이브러리 불러오기

# %%
from surprise import SVD
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split 

# 데이터 불러오기
data = Dataset.load_builtin('ml-100k')

# 가공, surprise.dataset.DatasetAutoFolds ==> pandas DataFrame으로 변경 (옵션)
# 데이터 엔지니어, 분석가들이 해야 하는 역할


# 데이터 분할 
trainset, testset = train_test_split(data, test_size=.25, random_state=0)

# %% [markdown]
# # 모델링

# %%
algo = SVD(random_state=0)
algo.fit(trainset)

# %% [markdown]
# # 테스트

# %%
predictions = algo.test(testset)
print(len(predictions), type(predictions))
predictions[:3]
# Out:
# 25000 <class 'list'>
# [Prediction(uid='120', iid='282', r_ui=4.0, est=3.5114147666251547, details={'was_impossible': False}),
#  Prediction(uid='882', iid='291', r_ui=4.0, est=3.573872419581491, details={'was_impossible': False}),
#  Prediction(uid='535', iid='507', r_ui=5.0, est=4.033583485472447, details={'was_impossible': False})]

# %%
# 프로젝트 할 때, 결괏값을 pandas 데이터프레임으로 만들고 나서 DB에 저장, CSV로 내보내기 하거나 등 작업을 수행하면 됨
# 각 개별적인 인수에 접근하는 방식 기억
for pred in predictions[:3]:
    print(pred.uid, pred.iid, pred.est, pred.details)
# Out:
# 120 282 3.5114147666251547 {'was_impossible': False}
# 882 291 3.573872419581491 {'was_impossible': False}
# 535 507 4.033583485472447 {'was_impossible': False}

# %%
# 예시 
uid = str(120)  # 숫자를 문자열로 형변환
iid = str(282)  # 숫자를 문자열로 형변환
pred = algo.predict(uid, iid)
print(pred)
# Out:
# user: 120        item: 282        r_ui = None   est = 3.51   {'was_impossible': False}

# %% [markdown]
# # 평가

# %%
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9467
# 0.9466860806937948

# %% [markdown]
# # 신규 데이터로 추천시스템

# %%
import pandas as pd 

ratings = pd.read_csv('data/ml-latest-small/ratings.csv')
ratings.to_csv('data/ml-latest-small/ratings_noh2.csv', index=False, header=False)

# %%
from surprise import Reader, Dataset 
reader = Reader(line_format='user item rating timestamp', sep=',', rating_scale=(0.5, 5))
data = Dataset.load_from_file('data/ml-latest-small/ratings_noh.csv', reader=reader)

trainset, testset = train_test_split(data, test_size=.25, random_state=0)

algo = SVD(n_factors=50, random_state=0)

# 학습 데이터 세트로 학습 후, 테스트 데이터 적용
algo.fit(trainset)
predictions = algo.test(testset)
accuracy.rmse(predictions)
# Out:
# RMSE: 0.8682
# 0.8681952927143516

# %% [markdown]
# # 데이터 활용

# %%
import pandas as pd 
from surprise import Reader, Dataset 

ratings = pd.read_csv('data/ml-latest-small/ratings.csv') # 컬럼 존재
reader = Reader(rating_scale=(0.5, 5))

# ratings DataFrame에서 컬럼은 사용자 아이디, 아이템 아이디, 평점 순서 
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

trainset, testset = train_test_split(data, test_size=.25, random_state=0)
algo = SVD(n_factors=50, random_state=0)

# 학습 데이터 세트로 학습 후, 테스트 데이터 적용
algo.fit(trainset)
predictions = algo.test(testset)
accuracy.rmse(predictions)
# Out:
# RMSE: 0.8682
# 0.8681952927143516

# %% [markdown]
# # 교차 검증과 하이퍼 파라미터 튜닝

# %%
import pandas as pd 
from surprise import Reader, Dataset 
from surprise.model_selection import cross_validate

ratings = pd.read_csv('data/ml-latest-small/ratings.csv') # 컬럼 존재
reader = Reader(rating_scale=(0.5, 5))

# ratings DataFrame에서 컬럼은 사용자 아이디, 아이템 아이디, 평점 순서 
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)
algo = SVD(random_state=0)
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8733  0.8717  0.8655  0.8799  0.8811  0.8743  0.0057
# MAE (testset)     0.6720  0.6705  0.6641  0.6773  0.6762  0.6720  0.0047
# Fit time          0.44    0.43    0.43    0.39    0.41    0.42    0.02
# Test time         0.04    0.04    0.04    0.04    0.04    0.04    0.00
# {'test_rmse': array([0.87332827, 0.87165013, 0.86550618, 0.87986284, 0.88114387]),
#  'test_mae': array([0.67199708, 0.67052009, 0.66409951, 0.67733718, 0.67615924]),
#  'fit_time': (0.4375894069671631,
#   0.43001556396484375,
#   0.4310905933380127,
#   0.3860933780670166,
#   0.4079935550689697),
#  'test_time': (0.043997764587402344,
#   0.044985055923461914,
#   0.040946245193481445,
#   0.04200029373168945,
#   0.039000511169433594)}

# %%
from surprise.model_selection import GridSearchCV
param_grid = {'n_epochs': [20, 40, 60], 'n_factors': [50, 100, 200]}

gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3)
gs.fit(data)

print(gs.best_score['rmse'])
print(gs.best_params['rmse'])
# Out:
# 0.877334127095764
# {'n_epochs': 20, 'n_factors': 50}

# %% [markdown]
# # DatasetAutoFolds 클래스 활용

# %%
from surprise.dataset import DatasetAutoFolds

reader = Reader(line_format='user item rating timestamp', sep=',', rating_scale=(0.5, 5))
data_folds = DatasetAutoFolds(ratings_file = 'data/ml-latest-small/ratings_noh.csv', reader=reader)

# 전체 데이터를 학습데이터로 생성함
trainset = data_folds.build_full_trainset()

# 모델 만들기
algo = SVD(n_epochs=20, n_factors=50, random_state=0)
algo.fit(trainset)

# %% [markdown]
# - 모델 테스트

# %%
ratings = pd.read_csv('data/ml-latest-small/ratings.csv') # 컬럼 존재
movies = pd.read_csv('data/ml-latest-small/movies.csv')

movieIds = ratings[ratings['userId'] == 9]['movieId']
if movieIds[movieIds==42].count() == 0:
    print('사용자 아이디 9는 영화 아이디 42의 평점 없음')

print(movies[movies['movieId']==42])
# Out:
# 사용자 아이디 9는 영화 아이디 42의 평점 없음
#     movieId                   title              genres
# 38       42  Dead Presidents (1995)  Action|Crime|Drama

# %%
# 예시 
uid = str(9)  # 숫자를 문자열로 형변환
iid = str(42)  # 숫자를 문자열로 형변환
pred = algo.predict(uid, iid)
print(pred)
# Out:
# user: 9          item: 42         r_ui = None   est = 3.13   {'was_impossible': False}

# %% [markdown]
# # 아직 보지 않은 모든 영화 예측
# - 특정 사용자가 본 영화 목록 존재
# - 전체 영화 목록 존재

# %%
def get_unseen_movies(ratings, movies, userId):
    seen_movies = ratings[ratings['userId'] == userId]['movieId'].tolist()
    total_movies = movies['movieId'].tolist()
    
    # 모든 영화들의 movieId 중 이미 평점을 매긴 영화의 movieId를 제외하여 리스트로 생성
    unseen_movies = [movie for movie in total_movies if movie not in seen_movies]
    print('평점 매긴 영화수:',len(seen_movies), '추천대상 영화수:',len(unseen_movies), \
          '전체 영화수:',len(total_movies))
    return unseen_movies

unseen_movies = get_unseen_movies(ratings, movies, 9)
# Out:
# 평점 매긴 영화수: 46 추천대상 영화수: 9696 전체 영화수: 9742

# %% [markdown]
# # 예측

# %%
userId = 12
unseen_movies = get_unseen_movies(ratings, movies, userId)
predictions = [algo.predict(str(userId), str(movieId)) for movieId in unseen_movies]

# 미션 : DataFrame으로 만들어서 CSV로 내보내기 결과 내보내기
# 필드명 : 사용자명, 영화제목, 예측평점
#
# Out:
# 평점 매긴 영화수: 32 추천대상 영화수: 9710 전체 영화수: 9742
# [Prediction(uid='12', iid='1', r_ui=None, est=4.9634699968292235, details={'was_impossible': False}),
#  Prediction(uid='12', iid='2', r_ui=None, est=4.441149871169427, details={'was_impossible': False}),
#  Prediction(uid='12', iid='3', r_ui=None, est=4.101890497903253, details={'was_impossible': False}),
#  Prediction(uid='12', iid='4', r_ui=None, est=3.95179673606818, details={'was_impossible': False}),
#  Prediction(uid='12', iid='5', r_ui=None, est=3.909789011257087, details={'was_impossible': False}),
#  Prediction(uid='12', iid='6', r_ui=None, est=4.891645645907925, details={'was_impossible': False}),
#  Prediction(uid='12', iid='7', r_ui=None, est=3.859949824627277, details={'was_impossible': False}),
#  Prediction(uid='12', iid='8', r_ui=None, est=4.111049035100181, details={'was_impossible': False}),
#  Prediction(uid='12', iid='9', r_ui=None, est=3.87504555805796, details={'was_impossible': False}),
#  Prediction(uid='12', iid='10', r_ui=None, est=4.404266835448777, details={'was_impossible': False}),
#  Prediction(uid='12', iid='11', r_ui=None, est=4.61468604679146, details={'was_impossible': False}),
#  Prediction(uid='12', iid='12', r_ui=None, est=3.5860565324699962, details={'was_impossible': False}),
#  Prediction(uid='12', iid='13', r_ui=None, est=4.341701255230369, details={'was_impossible': False}),
#  Prediction(uid='12', iid='14', r_ui=None, est=4.463223084431774, details={'was_impossible': False}),
#  Prediction(uid='12', iid='15', r_ui=None, est=4.192010717859418, details={'was_impossible': False}),
#  Prediction(uid='12', iid='16', r_ui=None, est=4.860350896596043, details={'was_impossible': False}),
#  Prediction(uid='12', iid='17', r_ui=None, est=4.656821738389713, details={'was_impossible': False}),
#  Prediction(uid='12', iid='18', r_ui=None, est=4.410362960090755, details={'was_impossible': False}),
#  Prediction(uid='12', iid='19', r_ui=None, est=3.589509071112385, details={'was_impossible': False}),
#  Prediction(uid='12', iid='20', r_ui=None, est=3.779729375899592, details={'was_impossible': False}),
#  Prediction(uid='12', iid='21', r_ui=None, est=4.3931434155324816, details={'was_impossible': False}),
#  Prediction(uid='12', iid='22', r_ui=None, est=4.467362803552072, details={'was_impossible': False}),
#  Prediction(uid='12', iid='23', r_ui=None, est=4.057836130426222, details={'was_impossible': False}),
#  Prediction(uid='12', iid='24', r_ui=None, est=4.207070827153143, details={'was_impossible': False}),
#  Prediction(uid='12', iid='25', r_ui=None, est=4.327743794524871, details={'was_impossible': False}),
#  Prediction(uid='12', iid='26', r_ui=None, est=4.551127531862374, details={'was_impossible': False}),
#  Prediction(uid='12', iid='27', r_ui=None, est=4.154537949632114, details={'was_impossible': False}),
#  Prediction(uid='12', iid='28', r_ui=None, est=4.970600017902185, details={'was_impossible': False}),
#  Prediction(uid='12', iid='29', r_ui=None, est=4.78667391819769, details={'was_impossible': False}),
#  Prediction(uid='12', iid='30', r_ui=None, est=4.218821037809671, details={'was_impossible': False}),
#  Prediction(uid='12', iid='31', r_ui=None, est=4.112557805394778, details={'was_impossible': False}),
#  Prediction(uid='12', iid='32', r_ui=None, est=4.788591109917139, details={'was_impossible': False}),
#  Prediction(uid='12', iid='34', r_ui=None, est=4.66395200413937, details={'was_impossible': False}),
#  Prediction(uid='12', iid='36', r_ui=None, est=4.702587143211413, details={'was_impossible': False}),
#  Prediction(uid='12', iid='38', r_ui=None, est=4.1578037066822935, details={'was_impossible': False}),
#  Prediction(uid='12', iid='40', r_ui=None, est=4.520171081182115, details={'was_impossible': False}),
#  Prediction(uid='12', iid='41', r_ui=None, est=4.673954553142938, details={'was_impossible': False}),
#  Prediction(uid='12', iid='42', r_ui=None, est=4.31457215105291, details={'was_impossible': False}),
#  Prediction(uid='12', iid='43', r_ui=None, est=4.248490251134295, details={'was_impossible': False}),
#  Prediction(uid='12', iid='44', r_ui=None, est=3.7477094900466463, details={'was_impossible': False}),
#  Prediction(uid='12', iid='45', r_ui=None, est=4.519943421674863, details={'was_impossible': False}),
#  Prediction(uid='12', iid='46', r_ui=None, est=4.133724577180793, details={'was_impossible': False}),
#  Prediction(uid='12', iid='47', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='48', r_ui=None, est=4.097695639839138, details={'was_impossible': False}),
#  Prediction(uid='12', iid='49', r_ui=None, est=4.195494265091533, details={'was_impossible': False}),
#  Prediction(uid='12', iid='50', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='52', r_ui=None, est=4.448026937374262, details={'was_impossible': False}),
#  Prediction(uid='12', iid='53', r_ui=None, est=4.595899591326256, details={'was_impossible': False}),
#  Prediction(uid='12', iid='54', r_ui=None, est=4.147125957511914, details={'was_impossible': False}),
#  Prediction(uid='12', iid='55', r_ui=None, est=4.532653376997935, details={'was_impossible': False}),
#  Prediction(uid='12', iid='57', r_ui=None, est=4.27973065738504, details={'was_impossible': False}),
#  Prediction(uid='12', iid='58', r_ui=None, est=4.946630956418326, details={'was_impossible': False}),
#  Prediction(uid='12', iid='60', r_ui=None, est=4.228242787189368, details={'was_impossible': False}),
#  Prediction(uid='12', iid='61', r_ui=None, est=4.474087955105435, details={'was_impossible': False}),
#  Prediction(uid='12', iid='62', r_ui=None, est=4.610736526532885, details={'was_impossible': False}),
#  Prediction(uid='12', iid='63', r_ui=None, est=4.159176700229397, details={'was_impossible': False}),
#  Prediction(uid='12', iid='64', r_ui=None, est=4.00620527644526, details={'was_impossible': False}),
#  Prediction(uid='12', iid='65', r_ui=None, est=3.570506365320796, details={'was_impossible': False}),
#  Prediction(uid='12', iid='66', r_ui=None, est=3.8719086715562194, details={'was_impossible': False}),
#  Prediction(uid='12', iid='68', r_ui=None, est=4.280669393284502, details={'was_impossible': False}),
#  Prediction(uid='12', iid='69', r_ui=None, est=4.637816951711379, details={'was_impossible': False}),
#  Prediction(uid='12', iid='70', r_ui=None, est=4.424463492496536, details={'was_impossible': False}),
#  Prediction(uid='12', iid='71', r_ui=None, est=3.8404132053933435, details={'was_impossible': False}),
#  Prediction(uid='12', iid='72', r_ui=None, est=4.2582825366212775, details={'was_impossible': False}),
#  Prediction(uid='12', iid='73', r_ui=None, est=4.354763294221097, details={'was_impossible': False}),
#  Prediction(uid='12', iid='74', r_ui=None, est=4.491524308673942, details={'was_impossible': False}),
#  Prediction(uid='12', iid='75', r_ui=None, est=3.9300343212913273, details={'was_impossible': False}),
#  Prediction(uid='12', iid='76', r_ui=None, est=4.3627442064606425, details={'was_impossible': False}),
#  Prediction(uid='12', iid='77', r_ui=None, est=4.478291926993534, details={'was_impossible': False}),
#  Prediction(uid='12', iid='78', r_ui=None, est=4.5144241192335555, details={'was_impossible': False}),
#  Prediction(uid='12', iid='79', r_ui=None, est=3.9186859365648425, details={'was_impossible': False}),
#  Prediction(uid='12', iid='80', r_ui=None, est=4.49946719071576, details={'was_impossible': False}),
#  Prediction(uid='12', iid='81', r_ui=None, est=4.016764287524991, details={'was_impossible': False}),
#  Prediction(uid='12', iid='82', r_ui=None, est=4.494701848851949, details={'was_impossible': False}),
#  Prediction(uid='12', iid='83', r_ui=None, est=4.30285372859882, details={'was_impossible': False}),
#  Prediction(uid='12', iid='85', r_ui=None, est=4.778911259896252, details={'was_impossible': False}),
#  Prediction(uid='12', iid='86', r_ui=None, est=4.614758950126926, details={'was_impossible': False}),
#  Prediction(uid='12', iid='87', r_ui=None, est=4.003568514490283, details={'was_impossible': False}),
#  Prediction(uid='12', iid='88', r_ui=None, est=4.073304143708907, details={'was_impossible': False}),
#  Prediction(uid='12', iid='89', r_ui=None, est=4.4572262719197315, details={'was_impossible': False}),
#  Prediction(uid='12', iid='92', r_ui=None, est=4.0415753604654245, details={'was_impossible': False}),
#  Prediction(uid='12', iid='93', r_ui=None, est=4.162939996315108, details={'was_impossible': False}),
#  Prediction(uid='12', iid='94', r_ui=None, est=4.692788905123573, details={'was_impossible': False}),
#  Prediction(uid='12', iid='95', r_ui=None, est=4.01764776854056, details={'was_impossible': False}),
#  Prediction(uid='12', iid='96', r_ui=None, est=4.424686367002348, details={'was_impossible': False}),
#  Prediction(uid='12', iid='97', r_ui=None, est=4.518225452077414, details={'was_impossible': False}),
#  Prediction(uid='12', iid='99', r_ui=None, est=4.561632005668149, details={'was_impossible': False}),
#  Prediction(uid='12', iid='100', r_ui=None, est=3.982763502775278, details={'was_impossible': False}),
#  Prediction(uid='12', iid='101', r_ui=None, est=4.597396966266713, details={'was_impossible': False}),
#  Prediction(uid='12', iid='102', r_ui=None, est=3.874480068673241, details={'was_impossible': False}),
#  Prediction(uid='12', iid='103', r_ui=None, est=4.122451765672458, details={'was_impossible': False}),
#  Prediction(uid='12', iid='104', r_ui=None, est=4.570956762927247, details={'was_impossible': False}),
#  Prediction(uid='12', iid='105', r_ui=None, est=4.224221344375862, details={'was_impossible': False}),
#  Prediction(uid='12', iid='106', r_ui=None, est=4.423401903824538, details={'was_impossible': False}),
#  Prediction(uid='12', iid='107', r_ui=None, est=4.358870914317569, details={'was_impossible': False}),
#  Prediction(uid='12', iid='108', r_ui=None, est=4.404919043939903, details={'was_impossible': False}),
#  Prediction(uid='12', iid='110', r_ui=None, est=4.920836498777025, details={'was_impossible': False}),
#  Prediction(uid='12', iid='111', r_ui=None, est=4.892946214139731, details={'was_impossible': False}),
#  Prediction(uid='12', iid='112', r_ui=None, est=4.359917163635901, details={'was_impossible': False}),
#  Prediction(uid='12', iid='113', r_ui=None, est=4.2806326005794775, details={'was_impossible': False}),
#  Prediction(uid='12', iid='116', r_ui=None, est=4.547274482453618, details={'was_impossible': False}),
#  Prediction(uid='12', iid='117', r_ui=None, est=4.390431125162539, details={'was_impossible': False}),
#  Prediction(uid='12', iid='118', r_ui=None, est=4.270758248141238, details={'was_impossible': False}),
#  Prediction(uid='12', iid='119', r_ui=None, est=4.2871808510019696, details={'was_impossible': False}),
#  Prediction(uid='12', iid='121', r_ui=None, est=4.473311121093236, details={'was_impossible': False}),
#  Prediction(uid='12', iid='122', r_ui=None, est=3.872990800151578, details={'was_impossible': False}),
#  Prediction(uid='12', iid='123', r_ui=None, est=4.578050552624747, details={'was_impossible': False}),
#  Prediction(uid='12', iid='125', r_ui=None, est=4.527495324097592, details={'was_impossible': False}),
#  Prediction(uid='12', iid='126', r_ui=None, est=3.6760482158787955, details={'was_impossible': False}),
#  Prediction(uid='12', iid='128', r_ui=None, est=4.503975330568641, details={'was_impossible': False}),
#  Prediction(uid='12', iid='129', r_ui=None, est=4.213764234970384, details={'was_impossible': False}),
#  Prediction(uid='12', iid='132', r_ui=None, est=4.208295531698173, details={'was_impossible': False}),
#  Prediction(uid='12', iid='135', r_ui=None, est=4.1110686838361765, details={'was_impossible': False}),
#  Prediction(uid='12', iid='137', r_ui=None, est=4.452235919570714, details={'was_impossible': False}),
#  Prediction(uid='12', iid='140', r_ui=None, est=4.266085673392523, details={'was_impossible': False}),
#  Prediction(uid='12', iid='141', r_ui=None, est=4.349924309181182, details={'was_impossible': False}),
#  Prediction(uid='12', iid='144', r_ui=None, est=4.2928304997618545, details={'was_impossible': False}),
#  Prediction(uid='12', iid='145', r_ui=None, est=4.156388795235474, details={'was_impossible': False}),
#  Prediction(uid='12', iid='146', r_ui=None, est=4.498417788726519, details={'was_impossible': False}),
#  Prediction(uid='12', iid='147', r_ui=None, est=4.563587781634835, details={'was_impossible': False}),
#  Prediction(uid='12', iid='148', r_ui=None, est=4.403222414173917, details={'was_impossible': False}),
#  Prediction(uid='12', iid='149', r_ui=None, est=4.235563846459887, details={'was_impossible': False}),
#  Prediction(uid='12', iid='150', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='151', r_ui=None, est=4.459975637384899, details={'was_impossible': False}),
#  Prediction(uid='12', iid='152', r_ui=None, est=4.097424163626836, details={'was_impossible': False}),
#  Prediction(uid='12', iid='153', r_ui=None, est=3.9222842450473703, details={'was_impossible': False}),
#  Prediction(uid='12', iid='154', r_ui=None, est=4.622837195929421, details={'was_impossible': False}),
#  Prediction(uid='12', iid='155', r_ui=None, est=3.984438311630015, details={'was_impossible': False}),
#  Prediction(uid='12', iid='156', r_ui=None, est=4.34680793530775, details={'was_impossible': False}),
#  Prediction(uid='12', iid='157', r_ui=None, est=4.247017064649853, details={'was_impossible': False}),
#  Prediction(uid='12', iid='158', r_ui=None, est=3.976052331009066, details={'was_impossible': False}),
#  Prediction(uid='12', iid='159', r_ui=None, est=4.043804126876168, details={'was_impossible': False}),
#  Prediction(uid='12', iid='160', r_ui=None, est=4.016457858894611, details={'was_impossible': False}),
#  Prediction(uid='12', iid='161', r_ui=None, est=4.54324577672405, details={'was_impossible': False}),
#  Prediction(uid='12', iid='162', r_ui=None, est=4.793699091254613, details={'was_impossible': False}),
#  Prediction(uid='12', iid='163', r_ui=None, est=4.504116468314347, details={'was_impossible': False}),
#  Prediction(uid='12', iid='164', r_ui=None, est=4.401453504321341, details={'was_impossible': False}),
#  Prediction(uid='12', iid='165', r_ui=None, est=4.513850210133023, details={'was_impossible': False}),
#  Prediction(uid='12', iid='166', r_ui=None, est=4.079703235658631, details={'was_impossible': False}),
#  Prediction(uid='12', iid='169', r_ui=None, est=3.8728100709875437, details={'was_impossible': False}),
#  Prediction(uid='12', iid='170', r_ui=None, est=4.403839329378728, details={'was_impossible': False}),
#  Prediction(uid='12', iid='171', r_ui=None, est=4.523216497011924, details={'was_impossible': False}),
#  Prediction(uid='12', iid='172', r_ui=None, est=3.6847826011000584, details={'was_impossible': False}),
#  Prediction(uid='12', iid='173', r_ui=None, est=3.699167402892232, details={'was_impossible': False}),
#  Prediction(uid='12', iid='174', r_ui=None, est=3.794700683016531, details={'was_impossible': False}),
#  Prediction(uid='12', iid='175', r_ui=None, est=4.815134544496131, details={'was_impossible': False}),
#  Prediction(uid='12', iid='176', r_ui=None, est=4.983909779676498, details={'was_impossible': False}),
#  Prediction(uid='12', iid='177', r_ui=None, est=3.9556067994606505, details={'was_impossible': False}),
#  Prediction(uid='12', iid='178', r_ui=None, est=4.186008490856176, details={'was_impossible': False}),
#  Prediction(uid='12', iid='179', r_ui=None, est=4.001485579953312, details={'was_impossible': False}),
#  Prediction(uid='12', iid='180', r_ui=None, est=4.219700875721921, details={'was_impossible': False}),
#  Prediction(uid='12', iid='181', r_ui=None, est=3.5632811133662226, details={'was_impossible': False}),
#  Prediction(uid='12', iid='183', r_ui=None, est=4.373240927127514, details={'was_impossible': False}),
#  Prediction(uid='12', iid='184', r_ui=None, est=4.428864570766324, details={'was_impossible': False}),
#  Prediction(uid='12', iid='185', r_ui=None, est=4.064087664163053, details={'was_impossible': False}),
#  Prediction(uid='12', iid='186', r_ui=None, est=4.002008928766727, details={'was_impossible': False}),
#  Prediction(uid='12', iid='187', r_ui=None, est=4.563086217228033, details={'was_impossible': False}),
#  Prediction(uid='12', iid='188', r_ui=None, est=4.377517417819452, details={'was_impossible': False}),
#  Prediction(uid='12', iid='189', r_ui=None, est=4.2651289824190215, details={'was_impossible': False}),
#  Prediction(uid='12', iid='190', r_ui=None, est=4.068375693227397, details={'was_impossible': False}),
#  Prediction(uid='12', iid='191', r_ui=None, est=4.064542766296156, details={'was_impossible': False}),
#  Prediction(uid='12', iid='193', r_ui=None, est=3.3245699995732636, details={'was_impossible': False}),
#  Prediction(uid='12', iid='194', r_ui=None, est=4.575362820951047, details={'was_impossible': False}),
#  Prediction(uid='12', iid='195', r_ui=None, est=4.206225431137851, details={'was_impossible': False}),
#  Prediction(uid='12', iid='196', r_ui=None, est=3.6437595999036247, details={'was_impossible': False}),
#  Prediction(uid='12', iid='198', r_ui=None, est=4.599480998353634, details={'was_impossible': False}),
#  Prediction(uid='12', iid='199', r_ui=None, est=4.557029260054701, details={'was_impossible': False}),
#  Prediction(uid='12', iid='201', r_ui=None, est=4.226615106711828, details={'was_impossible': False}),
#  Prediction(uid='12', iid='202', r_ui=None, est=4.305091401160451, details={'was_impossible': False}),
#  Prediction(uid='12', iid='203', r_ui=None, est=4.421105616065997, details={'was_impossible': False}),
#  Prediction(uid='12', iid='204', r_ui=None, est=3.6062866446315174, details={'was_impossible': False}),
#  Prediction(uid='12', iid='205', r_ui=None, est=4.2202145321846265, details={'was_impossible': False}),
#  Prediction(uid='12', iid='206', r_ui=None, est=4.299527597970536, details={'was_impossible': False}),
#  Prediction(uid='12', iid='207', r_ui=None, est=4.46996778981559, details={'was_impossible': False}),
#  Prediction(uid='12', iid='208', r_ui=None, est=3.863611664215623, details={'was_impossible': False}),
#  Prediction(uid='12', iid='209', r_ui=None, est=4.46690980783783, details={'was_impossible': False}),
#  Prediction(uid='12', iid='210', r_ui=None, est=4.334832750028102, details={'was_impossible': False}),
#  Prediction(uid='12', iid='211', r_ui=None, est=4.435227102616778, details={'was_impossible': False}),
#  Prediction(uid='12', iid='212', r_ui=None, est=4.212017647083106, details={'was_impossible': False}),
#  Prediction(uid='12', iid='213', r_ui=None, est=4.688027234212394, details={'was_impossible': False}),
#  Prediction(uid='12', iid='214', r_ui=None, est=4.389278535566008, details={'was_impossible': False}),
#  Prediction(uid='12', iid='215', r_ui=None, est=4.879307681974397, details={'was_impossible': False}),
#  Prediction(uid='12', iid='216', r_ui=None, est=4.351084234008482, details={'was_impossible': False}),
#  Prediction(uid='12', iid='217', r_ui=None, est=3.8192981017508183, details={'was_impossible': False}),
#  Prediction(uid='12', iid='218', r_ui=None, est=4.259669315378351, details={'was_impossible': False}),
#  Prediction(uid='12', iid='219', r_ui=None, est=4.319572385426766, details={'was_impossible': False}),
#  Prediction(uid='12', iid='220', r_ui=None, est=4.27244273763855, details={'was_impossible': False}),
#  Prediction(uid='12', iid='223', r_ui=None, est=4.636776020140419, details={'was_impossible': False}),
#  Prediction(uid='12', iid='224', r_ui=None, est=4.6080190688072555, details={'was_impossible': False}),
#  Prediction(uid='12', iid='225', r_ui=None, est=4.497307295216596, details={'was_impossible': False}),
#  Prediction(uid='12', iid='227', r_ui=None, est=3.76589008310851, details={'was_impossible': False}),
#  Prediction(uid='12', iid='228', r_ui=None, est=4.002760839121273, details={'was_impossible': False}),
#  Prediction(uid='12', iid='229', r_ui=None, est=4.39422271011827, details={'was_impossible': False}),
#  Prediction(uid='12', iid='230', r_ui=None, est=4.457652984527441, details={'was_impossible': False}),
#  Prediction(uid='12', iid='231', r_ui=None, est=4.023768510311915, details={'was_impossible': False}),
#  Prediction(uid='12', iid='232', r_ui=None, est=4.66593039598299, details={'was_impossible': False}),
#  Prediction(uid='12', iid='233', r_ui=None, est=4.602878508791055, details={'was_impossible': False}),
#  Prediction(uid='12', iid='234', r_ui=None, est=3.7679790181852018, details={'was_impossible': False}),
#  Prediction(uid='12', iid='235', r_ui=None, est=4.561688258716866, details={'was_impossible': False}),
#  Prediction(uid='12', iid='236', r_ui=None, est=4.179196539013772, details={'was_impossible': False}),
#  Prediction(uid='12', iid='237', r_ui=None, est=4.266538396712306, details={'was_impossible': False}),
#  Prediction(uid='12', iid='238', r_ui=None, est=4.52210965374946, details={'was_impossible': False}),
#  Prediction(uid='12', iid='239', r_ui=None, est=4.026304414530128, details={'was_impossible': False}),
#  Prediction(uid='12', iid='240', r_ui=None, est=4.1287186987354705, details={'was_impossible': False}),
#  Prediction(uid='12', iid='241', r_ui=None, est=4.4480160081888815, details={'was_impossible': False}),
#  Prediction(uid='12', iid='242', r_ui=None, est=4.428449946101244, details={'was_impossible': False}),
#  Prediction(uid='12', iid='243', r_ui=None, est=4.2860989468296, details={'was_impossible': False}),
#  Prediction(uid='12', iid='246', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='247', r_ui=None, est=4.803445843140699, details={'was_impossible': False}),
#  Prediction(uid='12', iid='248', r_ui=None, est=4.227599515382879, details={'was_impossible': False}),
#  Prediction(uid='12', iid='249', r_ui=None, est=4.629301194854454, details={'was_impossible': False}),
#  Prediction(uid='12', iid='250', r_ui=None, est=4.207105895361098, details={'was_impossible': False}),
#  Prediction(uid='12', iid='251', r_ui=None, est=4.293955467875837, details={'was_impossible': False}),
#  Prediction(uid='12', iid='252', r_ui=None, est=4.43781848567332, details={'was_impossible': False}),
#  Prediction(uid='12', iid='253', r_ui=None, est=4.33869492198747, details={'was_impossible': False}),
#  Prediction(uid='12', iid='254', r_ui=None, est=4.351147053345362, details={'was_impossible': False}),
#  Prediction(uid='12', iid='255', r_ui=None, est=3.6972518827996006, details={'was_impossible': False}),
#  Prediction(uid='12', iid='257', r_ui=None, est=4.262196524168599, details={'was_impossible': False}),
#  Prediction(uid='12', iid='258', r_ui=None, est=3.8839901605314338, details={'was_impossible': False}),
#  Prediction(uid='12', iid='259', r_ui=None, est=4.1968045494832, details={'was_impossible': False}),
#  Prediction(uid='12', iid='260', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='262', r_ui=None, est=4.778269935883129, details={'was_impossible': False}),
#  Prediction(uid='12', iid='263', r_ui=None, est=4.502956259232934, details={'was_impossible': False}),
#  Prediction(uid='12', iid='265', r_ui=None, est=4.7065837759328275, details={'was_impossible': False}),
#  Prediction(uid='12', iid='266', r_ui=None, est=4.212208418160282, details={'was_impossible': False}),
#  Prediction(uid='12', iid='267', r_ui=None, est=3.914641788970428, details={'was_impossible': False}),
#  Prediction(uid='12', iid='269', r_ui=None, est=4.212124525287798, details={'was_impossible': False}),
#  Prediction(uid='12', iid='270', r_ui=None, est=4.319050450139282, details={'was_impossible': False}),
#  Prediction(uid='12', iid='271', r_ui=None, est=4.259080372390919, details={'was_impossible': False}),
#  Prediction(uid='12', iid='272', r_ui=None, est=4.866964462557699, details={'was_impossible': False}),
#  Prediction(uid='12', iid='273', r_ui=None, est=3.8940354740511594, details={'was_impossible': False}),
#  Prediction(uid='12', iid='274', r_ui=None, est=4.306309468581269, details={'was_impossible': False}),
#  Prediction(uid='12', iid='275', r_ui=None, est=3.9446036920361487, details={'was_impossible': False}),
#  Prediction(uid='12', iid='276', r_ui=None, est=4.124692404635014, details={'was_impossible': False}),
#  Prediction(uid='12', iid='278', r_ui=None, est=4.158022903924139, details={'was_impossible': False}),
#  Prediction(uid='12', iid='279', r_ui=None, est=4.263101106005464, details={'was_impossible': False}),
#  Prediction(uid='12', iid='280', r_ui=None, est=4.823712270819191, details={'was_impossible': False}),
#  Prediction(uid='12', iid='281', r_ui=None, est=4.584601280068393, details={'was_impossible': False}),
#  Prediction(uid='12', iid='282', r_ui=None, est=4.291192067385167, details={'was_impossible': False}),
#  Prediction(uid='12', iid='283', r_ui=None, est=4.4515322471651215, details={'was_impossible': False}),
#  Prediction(uid='12', iid='284', r_ui=None, est=4.564086152126459, details={'was_impossible': False}),
#  Prediction(uid='12', iid='285', r_ui=None, est=4.465257688317119, details={'was_impossible': False}),
#  Prediction(uid='12', iid='287', r_ui=None, est=4.3693206289278645, details={'was_impossible': False}),
#  Prediction(uid='12', iid='288', r_ui=None, est=4.130553259405541, details={'was_impossible': False}),
#  Prediction(uid='12', iid='289', r_ui=None, est=4.3157005987413894, details={'was_impossible': False}),
#  Prediction(uid='12', iid='290', r_ui=None, est=4.648346806676049, details={'was_impossible': False}),
#  Prediction(uid='12', iid='291', r_ui=None, est=4.160060598104035, details={'was_impossible': False}),
#  Prediction(uid='12', iid='292', r_ui=None, est=4.276251879569004, details={'was_impossible': False}),
#  Prediction(uid='12', iid='293', r_ui=None, est=4.855138807117587, details={'was_impossible': False}),
#  Prediction(uid='12', iid='294', r_ui=None, est=4.213108394087618, details={'was_impossible': False}),
#  Prediction(uid='12', iid='295', r_ui=None, est=4.323193604411462, details={'was_impossible': False}),
#  Prediction(uid='12', iid='296', r_ui=None, est=4.780077936754932, details={'was_impossible': False}),
#  Prediction(uid='12', iid='298', r_ui=None, est=4.39013106174659, details={'was_impossible': False}),
#  Prediction(uid='12', iid='299', r_ui=None, est=4.540712054914714, details={'was_impossible': False}),
#  Prediction(uid='12', iid='300', r_ui=None, est=4.509129494934681, details={'was_impossible': False}),
#  Prediction(uid='12', iid='301', r_ui=None, est=4.482191789066091, details={'was_impossible': False}),
#  Prediction(uid='12', iid='302', r_ui=None, est=4.266042454535241, details={'was_impossible': False}),
#  Prediction(uid='12', iid='303', r_ui=None, est=4.1034996585887225, details={'was_impossible': False}),
#  Prediction(uid='12', iid='304', r_ui=None, est=4.352037919930567, details={'was_impossible': False}),
#  Prediction(uid='12', iid='305', r_ui=None, est=3.9105741293551417, details={'was_impossible': False}),
#  Prediction(uid='12', iid='306', r_ui=None, est=4.926908102932449, details={'was_impossible': False}),
#  Prediction(uid='12', iid='307', r_ui=None, est=4.845282528685942, details={'was_impossible': False}),
#  Prediction(uid='12', iid='308', r_ui=None, est=4.752037391520873, details={'was_impossible': False}),
#  Prediction(uid='12', iid='310', r_ui=None, est=4.299716376573239, details={'was_impossible': False}),
#  Prediction(uid='12', iid='311', r_ui=None, est=4.224636077024787, details={'was_impossible': False}),
#  Prediction(uid='12', iid='312', r_ui=None, est=3.31825368523968, details={'was_impossible': False}),
#  Prediction(uid='12', iid='313', r_ui=None, est=4.4412597297222245, details={'was_impossible': False}),
#  Prediction(uid='12', iid='314', r_ui=None, est=4.46378505454018, details={'was_impossible': False}),
#  Prediction(uid='12', iid='315', r_ui=None, est=4.198819094978413, details={'was_impossible': False}),
#  Prediction(uid='12', iid='316', r_ui=None, est=4.2311181974587235, details={'was_impossible': False}),
#  Prediction(uid='12', iid='317', r_ui=None, est=4.3726717238195585, details={'was_impossible': False}),
#  Prediction(uid='12', iid='318', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='319', r_ui=None, est=4.658361805827712, details={'was_impossible': False}),
#  Prediction(uid='12', iid='320', r_ui=None, est=4.393145607820921, details={'was_impossible': False}),
#  Prediction(uid='12', iid='321', r_ui=None, est=4.519716390779485, details={'was_impossible': False}),
#  Prediction(uid='12', iid='322', r_ui=None, est=4.412803880094917, details={'was_impossible': False}),
#  Prediction(uid='12', iid='324', r_ui=None, est=4.485856862614371, details={'was_impossible': False}),
#  Prediction(uid='12', iid='325', r_ui=None, est=3.9666598876094867, details={'was_impossible': False}),
#  Prediction(uid='12', iid='326', r_ui=None, est=4.530707498391641, details={'was_impossible': False}),
#  Prediction(uid='12', iid='327', r_ui=None, est=3.806250032979376, details={'was_impossible': False}),
#  Prediction(uid='12', iid='328', r_ui=None, est=4.257200029861438, details={'was_impossible': False}),
#  Prediction(uid='12', iid='329', r_ui=None, est=4.209102620746686, details={'was_impossible': False}),
#  Prediction(uid='12', iid='330', r_ui=None, est=4.153048469352883, details={'was_impossible': False}),
#  Prediction(uid='12', iid='331', r_ui=None, est=4.352522606410806, details={'was_impossible': False}),
#  Prediction(uid='12', iid='332', r_ui=None, est=4.0318070983163965, details={'was_impossible': False}),
#  Prediction(uid='12', iid='333', r_ui=None, est=4.73255363733954, details={'was_impossible': False}),
#  Prediction(uid='12', iid='334', r_ui=None, est=4.746519992924899, details={'was_impossible': False}),
#  Prediction(uid='12', iid='335', r_ui=None, est=4.495229145262808, details={'was_impossible': False}),
#  Prediction(uid='12', iid='336', r_ui=None, est=4.338440010366422, details={'was_impossible': False}),
#  Prediction(uid='12', iid='337', r_ui=None, est=4.8074580284304105, details={'was_impossible': False}),
#  Prediction(uid='12', iid='338', r_ui=None, est=4.010420448995538, details={'was_impossible': False}),
#  Prediction(uid='12', iid='339', r_ui=None, est=4.566820619703889, details={'was_impossible': False}),
#  Prediction(uid='12', iid='340', r_ui=None, est=4.374914953643864, details={'was_impossible': False}),
#  Prediction(uid='12', iid='341', r_ui=None, est=4.337641038804197, details={'was_impossible': False}),
#  Prediction(uid='12', iid='342', r_ui=None, est=4.271917042253459, details={'was_impossible': False}),
#  Prediction(uid='12', iid='343', r_ui=None, est=4.167021057165598, details={'was_impossible': False}),
#  Prediction(uid='12', iid='344', r_ui=None, est=4.014989303936339, details={'was_impossible': False}),
#  Prediction(uid='12', iid='345', r_ui=None, est=4.4463576261608475, details={'was_impossible': False}),
#  Prediction(uid='12', iid='346', r_ui=None, est=4.468687346944449, details={'was_impossible': False}),
#  Prediction(uid='12', iid='347', r_ui=None, est=4.3682014331727625, details={'was_impossible': False}),
#  Prediction(uid='12', iid='348', r_ui=None, est=4.364147338287054, details={'was_impossible': False}),
#  Prediction(uid='12', iid='349', r_ui=None, est=4.556421265988145, details={'was_impossible': False}),
#  Prediction(uid='12', iid='350', r_ui=None, est=4.6175736885740495, details={'was_impossible': False}),
#  Prediction(uid='12', iid='351', r_ui=None, est=4.137884656557487, details={'was_impossible': False}),
#  Prediction(uid='12', iid='352', r_ui=None, est=4.242645705193176, details={'was_impossible': False}),
#  Prediction(uid='12', iid='353', r_ui=None, est=4.597033844278452, details={'was_impossible': False}),
#  Prediction(uid='12', iid='354', r_ui=None, est=4.449180819535273, details={'was_impossible': False}),
#  Prediction(uid='12', iid='355', r_ui=None, est=3.7254639303875776, details={'was_impossible': False}),
#  Prediction(uid='12', iid='356', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='358', r_ui=None, est=3.830674185382005, details={'was_impossible': False}),
#  Prediction(uid='12', iid='359', r_ui=None, est=4.350301317176084, details={'was_impossible': False}),
#  Prediction(uid='12', iid='360', r_ui=None, est=4.01517834236633, details={'was_impossible': False}),
#  Prediction(uid='12', iid='361', r_ui=None, est=4.1842617795199795, details={'was_impossible': False}),
#  Prediction(uid='12', iid='362', r_ui=None, est=4.681066239307454, details={'was_impossible': False}),
#  Prediction(uid='12', iid='363', r_ui=None, est=4.421020684463444, details={'was_impossible': False}),
#  Prediction(uid='12', iid='364', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='365', r_ui=None, est=4.35560268217168, details={'was_impossible': False}),
#  Prediction(uid='12', iid='366', r_ui=None, est=4.130328718244321, details={'was_impossible': False}),
#  Prediction(uid='12', iid='367', r_ui=None, est=4.424147313023776, details={'was_impossible': False}),
#  Prediction(uid='12', iid='368', r_ui=None, est=4.65331560111047, details={'was_impossible': False}),
#  Prediction(uid='12', iid='369', r_ui=None, est=4.4995219011545435, details={'was_impossible': False}),
#  Prediction(uid='12', iid='370', r_ui=None, est=4.222333221018451, details={'was_impossible': False}),
#  Prediction(uid='12', iid='371', r_ui=None, est=4.369447785567651, details={'was_impossible': False}),
#  Prediction(uid='12', iid='372', r_ui=None, est=3.844827229970696, details={'was_impossible': False}),
#  Prediction(uid='12', iid='373', r_ui=None, est=4.567374558626121, details={'was_impossible': False}),
#  Prediction(uid='12', iid='374', r_ui=None, est=3.279692915910883, details={'was_impossible': False}),
#  Prediction(uid='12', iid='376', r_ui=None, est=4.177243250767212, details={'was_impossible': False}),
#  Prediction(uid='12', iid='377', r_ui=None, est=4.85233646833908, details={'was_impossible': False}),
#  Prediction(uid='12', iid='378', r_ui=None, est=4.156319367068418, details={'was_impossible': False}),
#  Prediction(uid='12', iid='379', r_ui=None, est=3.8085442338390814, details={'was_impossible': False}),
#  Prediction(uid='12', iid='380', r_ui=None, est=4.695084412905552, details={'was_impossible': False}),
#  Prediction(uid='12', iid='381', r_ui=None, est=4.568945448828914, details={'was_impossible': False}),
#  Prediction(uid='12', iid='382', r_ui=None, est=4.170064423273333, details={'was_impossible': False}),
#  Prediction(uid='12', iid='383', r_ui=None, est=4.101827308048833, details={'was_impossible': False}),
#  Prediction(uid='12', iid='384', r_ui=None, est=4.422476238730619, details={'was_impossible': False}),
#  Prediction(uid='12', iid='385', r_ui=None, est=4.485437043826532, details={'was_impossible': False}),
#  Prediction(uid='12', iid='386', r_ui=None, est=4.366039179392781, details={'was_impossible': False}),
#  Prediction(uid='12', iid='387', r_ui=None, est=4.245140937886415, details={'was_impossible': False}),
#  Prediction(uid='12', iid='388', r_ui=None, est=4.382200013110542, details={'was_impossible': False}),
#  Prediction(uid='12', iid='389', r_ui=None, est=4.686749572367166, details={'was_impossible': False}),
#  Prediction(uid='12', iid='390', r_ui=None, est=4.577620254360264, details={'was_impossible': False}),
#  Prediction(uid='12', iid='391', r_ui=None, est=4.43186788094911, details={'was_impossible': False}),
#  Prediction(uid='12', iid='393', r_ui=None, est=3.8643883215834283, details={'was_impossible': False}),
#  Prediction(uid='12', iid='405', r_ui=None, est=3.857552529045643, details={'was_impossible': False}),
#  Prediction(uid='12', iid='406', r_ui=None, est=4.398507759083309, details={'was_impossible': False}),
#  Prediction(uid='12', iid='407', r_ui=None, est=4.465483433542631, details={'was_impossible': False}),
#  Prediction(uid='12', iid='408', r_ui=None, est=4.2358408107808145, details={'was_impossible': False}),
#  Prediction(uid='12', iid='409', r_ui=None, est=4.456273184914739, details={'was_impossible': False}),
#  Prediction(uid='12', iid='410', r_ui=None, est=4.0985474469773076, details={'was_impossible': False}),
#  Prediction(uid='12', iid='412', r_ui=None, est=4.39325180226001, details={'was_impossible': False}),
#  Prediction(uid='12', iid='413', r_ui=None, est=3.753705280797437, details={'was_impossible': False}),
#  Prediction(uid='12', iid='414', r_ui=None, est=4.108414525527582, details={'was_impossible': False}),
#  Prediction(uid='12', iid='415', r_ui=None, est=3.7439817420581156, details={'was_impossible': False}),
#  Prediction(uid='12', iid='416', r_ui=None, est=3.960201640495315, details={'was_impossible': False}),
#  Prediction(uid='12', iid='417', r_ui=None, est=4.655196407788182, details={'was_impossible': False}),
#  Prediction(uid='12', iid='418', r_ui=None, est=4.415400341459897, details={'was_impossible': False}),
#  Prediction(uid='12', iid='419', r_ui=None, est=3.8437454153636614, details={'was_impossible': False}),
#  Prediction(uid='12', iid='420', r_ui=None, est=3.709545057764801, details={'was_impossible': False}),
#  Prediction(uid='12', iid='421', r_ui=None, est=4.159147414104193, details={'was_impossible': False}),
#  Prediction(uid='12', iid='422', r_ui=None, est=4.423610467971142, details={'was_impossible': False}),
#  Prediction(uid='12', iid='423', r_ui=None, est=3.9832037022433346, details={'was_impossible': False}),
#  Prediction(uid='12', iid='424', r_ui=None, est=3.927144062435876, details={'was_impossible': False}),
#  Prediction(uid='12', iid='425', r_ui=None, est=4.47329754293462, details={'was_impossible': False}),
#  Prediction(uid='12', iid='426', r_ui=None, est=4.368488468392961, details={'was_impossible': False}),
#  Prediction(uid='12', iid='427', r_ui=None, est=3.8418652447153883, details={'was_impossible': False}),
#  Prediction(uid='12', iid='428', r_ui=None, est=4.7728455856640055, details={'was_impossible': False}),
#  Prediction(uid='12', iid='429', r_ui=None, est=4.053381158500995, details={'was_impossible': False}),
#  Prediction(uid='12', iid='430', r_ui=None, est=4.3323839449021015, details={'was_impossible': False}),
#  Prediction(uid='12', iid='431', r_ui=None, est=4.507917050741795, details={'was_impossible': False}),
#  Prediction(uid='12', iid='432', r_ui=None, est=3.6629437499985134, details={'was_impossible': False}),
#  Prediction(uid='12', iid='433', r_ui=None, est=4.270105189362288, details={'was_impossible': False}),
#  Prediction(uid='12', iid='434', r_ui=None, est=4.040179050921221, details={'was_impossible': False}),
#  Prediction(uid='12', iid='435', r_ui=None, est=3.4802203152380122, details={'was_impossible': False}),
#  Prediction(uid='12', iid='436', r_ui=None, est=4.091624285703839, details={'was_impossible': False}),
#  Prediction(uid='12', iid='437', r_ui=None, est=3.8294979842225483, details={'was_impossible': False}),
#  Prediction(uid='12', iid='438', r_ui=None, est=4.237738602267933, details={'was_impossible': False}),
#  Prediction(uid='12', iid='440', r_ui=None, est=4.439536173448739, details={'was_impossible': False}),
#  Prediction(uid='12', iid='441', r_ui=None, est=4.799145137157821, details={'was_impossible': False}),
#  Prediction(uid='12', iid='442', r_ui=None, est=3.89589077741293, details={'was_impossible': False}),
#  Prediction(uid='12', iid='444', r_ui=None, est=4.266435290373796, details={'was_impossible': False}),
#  Prediction(uid='12', iid='445', r_ui=None, est=4.22348882880199, details={'was_impossible': False}),
#  Prediction(uid='12', iid='446', r_ui=None, est=4.523965518669701, details={'was_impossible': False}),
#  Prediction(uid='12', iid='448', r_ui=None, est=4.442477847571494, details={'was_impossible': False}),
#  Prediction(uid='12', iid='449', r_ui=None, est=4.3495435984081325, details={'was_impossible': False}),
#  Prediction(uid='12', iid='450', r_ui=None, est=4.241423281033106, details={'was_impossible': False}),
#  Prediction(uid='12', iid='451', r_ui=None, est=4.433418697778183, details={'was_impossible': False}),
#  Prediction(uid='12', iid='452', r_ui=None, est=4.38440010784986, details={'was_impossible': False}),
#  Prediction(uid='12', iid='453', r_ui=None, est=4.213726726255758, details={'was_impossible': False}),
#  Prediction(uid='12', iid='454', r_ui=None, est=4.463345798552555, details={'was_impossible': False}),
#  Prediction(uid='12', iid='455', r_ui=None, est=3.600499529042272, details={'was_impossible': False}),
#  Prediction(uid='12', iid='456', r_ui=None, est=4.4604435248797705, details={'was_impossible': False}),
#  Prediction(uid='12', iid='457', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='458', r_ui=None, est=4.139675844682679, details={'was_impossible': False}),
#  Prediction(uid='12', iid='459', r_ui=None, est=3.9829721468134, details={'was_impossible': False}),
#  Prediction(uid='12', iid='460', r_ui=None, est=4.340086935451054, details={'was_impossible': False}),
#  Prediction(uid='12', iid='461', r_ui=None, est=4.182935705018988, details={'was_impossible': False}),
#  Prediction(uid='12', iid='464', r_ui=None, est=4.098430196543393, details={'was_impossible': False}),
#  Prediction(uid='12', iid='466', r_ui=None, est=3.97151428348744, details={'was_impossible': False}),
#  Prediction(uid='12', iid='467', r_ui=None, est=4.330870066854141, details={'was_impossible': False}),
#  Prediction(uid='12', iid='468', r_ui=None, est=4.1957353990425785, details={'was_impossible': False}),
#  Prediction(uid='12', iid='469', r_ui=None, est=4.322777782973561, details={'was_impossible': False}),
#  Prediction(uid='12', iid='470', r_ui=None, est=4.3351148240416375, details={'was_impossible': False}),
#  Prediction(uid='12', iid='471', r_ui=None, est=4.758785740073494, details={'was_impossible': False}),
#  Prediction(uid='12', iid='472', r_ui=None, est=4.056743842660194, details={'was_impossible': False}),
#  Prediction(uid='12', iid='473', r_ui=None, est=3.887050166198611, details={'was_impossible': False}),
#  Prediction(uid='12', iid='474', r_ui=None, est=4.625664003457754, details={'was_impossible': False}),
#  Prediction(uid='12', iid='475', r_ui=None, est=4.979217365027788, details={'was_impossible': False}),
#  Prediction(uid='12', iid='476', r_ui=None, est=4.185847647808407, details={'was_impossible': False}),
#  Prediction(uid='12', iid='477', r_ui=None, est=4.382439728168254, details={'was_impossible': False}),
#  Prediction(uid='12', iid='478', r_ui=None, est=4.368041818277281, details={'was_impossible': False}),
#  Prediction(uid='12', iid='479', r_ui=None, est=4.053928948930025, details={'was_impossible': False}),
#  Prediction(uid='12', iid='480', r_ui=None, est=4.736706684017291, details={'was_impossible': False}),
#  Prediction(uid='12', iid='481', r_ui=None, est=4.166557847466831, details={'was_impossible': False}),
#  Prediction(uid='12', iid='482', r_ui=None, est=4.603606192629778, details={'was_impossible': False}),
#  Prediction(uid='12', iid='484', r_ui=None, est=4.25000684989862, details={'was_impossible': False}),
#  Prediction(uid='12', iid='485', r_ui=None, est=3.9386007926355315, details={'was_impossible': False}),
#  Prediction(uid='12', iid='486', r_ui=None, est=4.262586645034863, details={'was_impossible': False}),
#  Prediction(uid='12', iid='487', r_ui=None, est=4.094760252136573, details={'was_impossible': False}),
#  Prediction(uid='12', iid='488', r_ui=None, est=4.424232177591602, details={'was_impossible': False}),
#  Prediction(uid='12', iid='489', r_ui=None, est=4.06145004326956, details={'was_impossible': False}),
#  Prediction(uid='12', iid='490', r_ui=None, est=3.8964118768709413, details={'was_impossible': False}),
#  Prediction(uid='12', iid='491', r_ui=None, est=4.439702955454332, details={'was_impossible': False}),
#  Prediction(uid='12', iid='492', r_ui=None, est=4.705235945965052, details={'was_impossible': False}),
#  Prediction(uid='12', iid='493', r_ui=None, est=4.560276727987891, details={'was_impossible': False}),
#  Prediction(uid='12', iid='494', r_ui=None, est=4.552959588500371, details={'was_impossible': False}),
#  Prediction(uid='12', iid='495', r_ui=None, est=4.544553829954338, details={'was_impossible': False}),
#  Prediction(uid='12', iid='496', r_ui=None, est=4.511818106367496, details={'was_impossible': False}),
#  Prediction(uid='12', iid='497', r_ui=None, est=4.761496310093438, details={'was_impossible': False}),
#  Prediction(uid='12', iid='499', r_ui=None, est=4.381314463101162, details={'was_impossible': False}),
#  Prediction(uid='12', iid='500', r_ui=None, est=4.503825742685942, details={'was_impossible': False}),
#  Prediction(uid='12', iid='501', r_ui=None, est=4.395592499125122, details={'was_impossible': False}),
#  Prediction(uid='12', iid='502', r_ui=None, est=3.6563006326322594, details={'was_impossible': False}),
#  Prediction(uid='12', iid='504', r_ui=None, est=4.569024372631029, details={'was_impossible': False}),
#  Prediction(uid='12', iid='505', r_ui=None, est=3.9563290156722086, details={'was_impossible': False}),
#  Prediction(uid='12', iid='506', r_ui=None, est=4.572800384263157, details={'was_impossible': False}),
#  Prediction(uid='12', iid='507', r_ui=None, est=4.387579264478382, details={'was_impossible': False}),
#  Prediction(uid='12', iid='508', r_ui=None, est=4.615033788753855, details={'was_impossible': False}),
#  Prediction(uid='12', iid='509', r_ui=None, est=4.430567015600693, details={'was_impossible': False}),
#  Prediction(uid='12', iid='510', r_ui=None, est=4.366075217562971, details={'was_impossible': False}),
#  Prediction(uid='12', iid='511', r_ui=None, est=4.2549067267225915, details={'was_impossible': False}),
#  Prediction(uid='12', iid='512', r_ui=None, est=4.298260087573227, details={'was_impossible': False}),
#  Prediction(uid='12', iid='513', r_ui=None, est=4.499668745455153, details={'was_impossible': False}),
#  Prediction(uid='12', iid='514', r_ui=None, est=4.463354384821907, details={'was_impossible': False}),
#  Prediction(uid='12', iid='515', r_ui=None, est=4.6915984879907455, details={'was_impossible': False}),
#  Prediction(uid='12', iid='516', r_ui=None, est=4.290852685042226, details={'was_impossible': False}),
#  Prediction(uid='12', iid='517', r_ui=None, est=4.417716163220555, details={'was_impossible': False}),
#  Prediction(uid='12', iid='518', r_ui=None, est=4.286050453612126, details={'was_impossible': False}),
#  Prediction(uid='12', iid='519', r_ui=None, est=3.609325871275952, details={'was_impossible': False}),
#  Prediction(uid='12', iid='520', r_ui=None, est=4.215784767719229, details={'was_impossible': False}),
#  Prediction(uid='12', iid='521', r_ui=None, est=4.46051587168207, details={'was_impossible': False}),
#  Prediction(uid='12', iid='522', r_ui=None, est=4.265530931699119, details={'was_impossible': False}),
#  Prediction(uid='12', iid='523', r_ui=None, est=4.425056167894566, details={'was_impossible': False}),
#  Prediction(uid='12', iid='524', r_ui=None, est=4.427932496539914, details={'was_impossible': False}),
#  Prediction(uid='12', iid='526', r_ui=None, est=4.387054675838719, details={'was_impossible': False}),
#  Prediction(uid='12', iid='527', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='528', r_ui=None, est=4.3117459491262, details={'was_impossible': False}),
#  Prediction(uid='12', iid='529', r_ui=None, est=4.838305465880569, details={'was_impossible': False}),
#  Prediction(uid='12', iid='531', r_ui=None, est=4.260085041584651, details={'was_impossible': False}),
#  Prediction(uid='12', iid='532', r_ui=None, est=4.059627934240333, details={'was_impossible': False}),
#  Prediction(uid='12', iid='533', r_ui=None, est=4.225242789167429, details={'was_impossible': False}),
#  Prediction(uid='12', iid='534', r_ui=None, est=4.510411234131079, details={'was_impossible': False}),
#  Prediction(uid='12', iid='535', r_ui=None, est=4.469424843850944, details={'was_impossible': False}),
#  Prediction(uid='12', iid='536', r_ui=None, est=4.41875720578515, details={'was_impossible': False}),
#  Prediction(uid='12', iid='537', r_ui=None, est=4.2396068170833905, details={'was_impossible': False}),
#  Prediction(uid='12', iid='538', r_ui=None, est=4.422730648873574, details={'was_impossible': False}),
#  Prediction(uid='12', iid='539', r_ui=None, est=4.521904724929589, details={'was_impossible': False}),
#  Prediction(uid='12', iid='540', r_ui=None, est=3.87620395503548, details={'was_impossible': False}),
# ...
#  Prediction(uid='12', iid='1124', r_ui=None, est=4.549138808984741, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1125', r_ui=None, est=4.519087073634488, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1126', r_ui=None, est=4.426747843692722, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1127', r_ui=None, est=4.516360034141246, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1128', r_ui=None, est=4.185565094429455, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1129', r_ui=None, est=4.446824810307499, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1130', r_ui=None, est=4.285971592563734, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1131', r_ui=None, est=4.626072812486195, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1132', r_ui=None, est=4.604751550984446, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1135', r_ui=None, est=4.287350928383634, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1136', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1137', r_ui=None, est=4.491506003040942, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1140', r_ui=None, est=4.5388366903211494, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1144', r_ui=None, est=4.3848971270523505, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1147', r_ui=None, est=4.4690795591661, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1148', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1150', r_ui=None, est=4.62459546444814, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1151', r_ui=None, est=4.5024987796104, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1156', r_ui=None, est=4.313951587125838, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1161', r_ui=None, est=4.528515450199203, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1162', r_ui=None, est=4.364276571414702, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1163', r_ui=None, est=4.190259634386311, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1167', r_ui=None, est=4.384052538925934, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1170', r_ui=None, est=4.159083257488822, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1171', r_ui=None, est=4.242098469529176, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1172', r_ui=None, est=4.938673526517124, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1173', r_ui=None, est=3.9331837326215684, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1175', r_ui=None, est=4.877127889125954, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1176', r_ui=None, est=4.503872284354062, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1177', r_ui=None, est=4.5707288090221185, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1178', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1179', r_ui=None, est=4.693972063283142, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1180', r_ui=None, est=4.484542592787852, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1183', r_ui=None, est=4.610427669864499, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1184', r_ui=None, est=4.478849187813226, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1185', r_ui=None, est=4.6244524228903225, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1186', r_ui=None, est=4.517931375194669, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1187', r_ui=None, est=4.389487679106165, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1188', r_ui=None, est=4.5236250533026485, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1189', r_ui=None, est=4.692041369599651, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1190', r_ui=None, est=4.413483543561069, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1191', r_ui=None, est=4.322294636361518, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1192', r_ui=None, est=4.61522833000989, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1193', r_ui=None, est=4.983515976983776, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1194', r_ui=None, est=4.501231994357798, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1196', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1197', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1198', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1199', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1200', r_ui=None, est=4.665823280037667, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1201', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1202', r_ui=None, est=4.586090878436534, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1203', r_ui=None, est=4.954600192105418, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1204', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1206', r_ui=None, est=4.506901769154517, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1207', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1208', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1209', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1210', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1211', r_ui=None, est=4.691563989198148, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1212', r_ui=None, est=4.9885383190900665, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1213', r_ui=None, est=4.929546402995948, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1214', r_ui=None, est=4.716263902893255, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1215', r_ui=None, est=4.9492116888087505, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1216', r_ui=None, est=4.361633185854864, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1217', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1218', r_ui=None, est=4.704454783420103, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1219', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1220', r_ui=None, est=4.702953312203182, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1221', r_ui=None, est=4.9577599536274, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1222', r_ui=None, est=4.970430028086469, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1223', r_ui=None, est=4.904541254372193, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1224', r_ui=None, est=4.764603550080656, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1225', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1226', r_ui=None, est=4.389510274144612, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1227', r_ui=None, est=4.931739911565482, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1228', r_ui=None, est=4.87109081034869, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1230', r_ui=None, est=4.780150259832475, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1231', r_ui=None, est=4.647603749385466, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1232', r_ui=None, est=4.692144179568817, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1233', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1234', r_ui=None, est=4.816556071759013, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1235', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1236', r_ui=None, est=4.777014175402838, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1237', r_ui=None, est=4.911899568113291, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1238', r_ui=None, est=4.801244154403218, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1240', r_ui=None, est=4.828447708094741, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1241', r_ui=None, est=4.79490355177771, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1242', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1243', r_ui=None, est=4.572146656745619, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1244', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1245', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1246', r_ui=None, est=4.883011789690926, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1247', r_ui=None, est=4.859536203681525, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1248', r_ui=None, est=4.965164666204938, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1249', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1250', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1251', r_ui=None, est=4.73213675276301, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1252', r_ui=None, est=4.933550702362333, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1253', r_ui=None, est=4.729035813424533, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1254', r_ui=None, est=4.444309018417445, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1255', r_ui=None, est=4.4793061832556464, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1256', r_ui=None, est=4.598834304704686, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1257', r_ui=None, est=4.549697031234732, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1258', r_ui=None, est=4.94269400547117, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1259', r_ui=None, est=4.859809211555725, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1260', r_ui=None, est=4.549343557743287, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1261', r_ui=None, est=4.934502419132216, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1262', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1263', r_ui=None, est=4.550297345817961, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1264', r_ui=None, est=4.354947016369111, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1266', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1267', r_ui=None, est=4.914501733807227, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1268', r_ui=None, est=4.488076473724943, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1269', r_ui=None, est=4.690875774157088, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1270', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1271', r_ui=None, est=4.5169564410001675, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1272', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1273', r_ui=None, est=4.776213770812531, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1274', r_ui=None, est=4.627677784052451, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1275', r_ui=None, est=4.672687390676813, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1276', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1277', r_ui=None, est=4.8883492612172805, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1278', r_ui=None, est=4.977913528099158, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1279', r_ui=None, est=4.540241368400282, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1280', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1281', r_ui=None, est=4.819502651036995, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1282', r_ui=None, est=4.832349450703986, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1283', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1284', r_ui=None, est=4.871817070692097, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1285', r_ui=None, est=4.640418776171299, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1286', r_ui=None, est=4.296241996928738, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1287', r_ui=None, est=4.7050163274604015, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1288', r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1289', r_ui=None, est=4.5569215265164065, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1290', r_ui=None, est=4.2412087417699, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1291', r_ui=None, est=4.985274985514354, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1292', r_ui=None, est=4.78396572723909, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1293', r_ui=None, est=4.683342348023277, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1295', r_ui=None, est=4.382783215758095, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1296', r_ui=None, est=4.729788570071416, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1297', r_ui=None, est=4.620283213007101, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1298', r_ui=None, est=4.687882969610819, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1299', r_ui=None, est=4.656483578476671, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1300', r_ui=None, est=4.623415020404896, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1301', r_ui=None, est=4.607430840600884, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1302', r_ui=None, est=4.379958009850666, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1303', r_ui=None, est=4.889285327362422, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1304', r_ui=None, est=4.79482260362579, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1305', r_ui=None, est=4.389969488922874, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1306', r_ui=None, est=4.157637831083977, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1307', r_ui=None, est=4.838178699828084, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1310', r_ui=None, est=4.458900898239241, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1312', r_ui=None, est=4.262026963695408, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1318', r_ui=None, est=4.283954613805856, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1320', r_ui=None, est=4.126923598691373, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1321', r_ui=None, est=4.44845919080858, details={'was_impossible': False}),
#  Prediction(uid='12', iid='1322', r_ui=None, est=4.0798041857367675, details={'was_impossible': False}),
#  ...]
